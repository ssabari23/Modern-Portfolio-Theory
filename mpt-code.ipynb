ATACONSUM.NS  TATAMOTORS.NS  TATASTEEL.NS  \
# 0     ...    634.049988     123.550003     487.049988     38.752563
# 1     ...    636.099976     124.449997     481.100006     38.423866
# 2     ...    637.349976     124.449997     486.649994     38.628708
# 3     ...    643.450012     125.199997     502.149994     39.948246
# 4     ...    640.750000     124.650002     497.750000     39.972065
# ...   ...           ...            ...            ...           ...
# 1231  ...    794.099976     718.500000     471.149994    112.180000
# 1232  ...    815.099976     726.950012     480.200012    112.745003
# 1233  ...    838.799988     726.650024     476.000000    111.625000
# 1234  ...    834.450012     728.000000     470.399994    110.099998
# 1235  ...    845.700012     743.450012     482.399994    111.144997
#
#            TCS.NS     TECHM.NS     TITAN.NS  ULTRACEMCO.NS      UPL.NS  \
# 0     1180.675049   488.000000   333.950012    3371.350098  439.100006
# 1     1184.125000   491.549988   348.149994    3326.699951  436.666656
# 2     1189.750000   500.600006   359.649994    3301.399902  445.033325
# 3     1167.199951   488.100006   358.049988    3382.850098  449.733337
# 4     1140.699951   469.750000   355.200012    3322.750000  439.933319
# ...           ...          ...          ...            ...         ...
# 1231  3696.100098  1785.000000  2331.300049    7245.049805  756.599976
# 1232  3706.550049  1806.099976  2379.850098    7406.100098  761.750000
# 1233  3694.699951  1786.849976  2402.149902    7420.950195  758.349976
# 1234  3733.750000  1799.949951  2437.300049    7397.200195  746.650024
# 1235  3738.350098  1790.550049  2522.399902    7591.049805  747.099976
#
#         WIPRO.NS
# 0     176.831299
# 1     175.125046
# 2     178.350037
# 3     180.150040
# 4     176.231293
# ...          ...
# 1231  699.599976
# 1232  705.450012
# 1233  703.700012
# 1234  714.099976
# 1235  715.349976
#
# [1236 rows x 49 columns]

# %%
df = df.set_index("DATE")

# %%
for col in df.columns:
    print(col)
# Out:
# ADANIENT.NS
# ADANIPORTS.NS
# APOLLOHOSP.NS
# ASIANPAINT.NS
# AXISBANK.NS
# BAJAJ-AUTO.NS
# BAJAJFINSV.NS
# BAJFINANCE.NS
# BHARTIARTL.NS
# BPCL.NS
# BRITANNIA.NS
# CIPLA.NS
# COALINDIA.NS
# DIVISLAB.NS
# DRREDDY.NS
# EICHERMOT.NS
# GRASIM.NS
# HCLTECH.NS
# HDFC.NS
# HDFCBANK.NS
# HEROMOTOCO.NS
# HINDALCO.NS
# HINDUNILVR.NS
# ICICIBANK.NS
# INDUSINDBK.NS
# INFY.NS
# ITC.NS
# JSWSTEEL.NS
# KOTAKBANK.NS
# LTI.NS
# M&M.NS
# MARUTI.NS
# NESTLEIND.NS
# NTPC.NS
# ONGC.NS
# POWERGRID.NS
# RELIANCE.NS
# SBIN.NS
# SUNPHARMA.NS
# TATACONSUM.NS
# TATAMOTORS.NS
# TATASTEEL.NS
# TCS.NS
# TECHM.NS
# TITAN.NS
# ULTRACEMCO.NS
# UPL.NS
# WIPRO.NS

# %%
df1 = df.copy()
df
# Out:
#             ADANIENT.NS  ADANIPORTS.NS  APOLLOHOSP.NS  ASIANPAINT.NS  \
# 06-01-2017   355.200012    3322.750000  439.933319  176.231293
# ...                 ...            ...         ...         ...
# 27-12-2021  2331.300049    7245.049805  756.599976  699.599976
# 28-12-2021  2379.850098    7406.100098  761.750000  705.450012
# 29-12-2021  2402.149902    7420.950195  758.349976  703.700012
# 30-12-2021  2437.300049    7397.200195  746.650024  714.099976
# 31-12-2021  2522.399902    7591.049805  747.099976  715.349976
#
# [1236 rows x 48 columns]

# %%
name = list(df)
name
# Out:
# ['ADANIENT.NS',
#  'ADANIPORTS.NS',
#  'APOLLOHOSP.NS',
#  'ASIANPAINT.NS',
#  'AXISBANK.NS',
#  'BAJAJ-AUTO.NS',
#  'BAJAJFINSV.NS',
#  'BAJFINANCE.NS',
#  'BHARTIARTL.NS',
#  'BPCL.NS',
#  'BRITANNIA.NS',
#  'CIPLA.NS',
#  'COALINDIA.NS',
#  'DIVISLAB.NS',
#  'DRREDDY.NS',
#  'EICHERMOT.NS',
#  'GRASIM.NS',
#  'HCLTECH.NS',
#  'HDFC.NS',
#  'HDFCBANK.NS',
#  'HEROMOTOCO.NS',
#  'HINDALCO.NS',
#  'HINDUNILVR.NS',
#  'ICICIBANK.NS',
#  'INDUSINDBK.NS',
#  'INFY.NS',
#  'ITC.NS',
#  'JSWSTEEL.NS',
#  'KOTAKBANK.NS',
#  'LTI.NS',
#  'M&M.NS',
#  'MARUTI.NS',
#  'NESTLEIND.NS',
#  'NTPC.NS',
#  'ONGC.NS',
#  'POWERGRID.NS',
#  'RELIANCE.NS',
#  'SBIN.NS',
#  'SUNPHARMA.NS',
#  'TATACONSUM.NS',
#  'TATAMOTORS.NS',
#  'TATASTEEL.NS',
#  'TCS.NS',
#  'TECHM.NS',
#  'TITAN.NS',
#  'ULTRACEMCO.NS',
#  'UPL.NS',
#  'WIPRO.NS']

# %% [markdown]
# # CAGR Function

# %%
def CAGR(df,name):
    
    #the initial price of stock 
    start_value = df[name].iloc[0]
    
    #the final price of stock 
    end_value = df[name].iloc[-1]
    
    #number of years being taken into account 
    n = 5
    
    #WRITE THE CAGR FUNCTION USING START VALUE, END VALUE AND NUMBER OF PERIODS
    cagr = (end_value/start_value)**(1/n) -1 
    
    return cagr

# %% [markdown]
# # VOLATILITY Function

# %%
def volatility(df,name):
    df[name] = df[name].pct_change()
    vol = df[name].std(ddof=0) * np.sqrt(252)
    return vol

# %% [markdown]
# # SHARPE Ratio Function

# %%
def sharpe(x,y,rf):
    
    #Sharpe Ratio formula using CAGR, Volatility and Risk-Free rate(0.06)
    sr = (x - 0.06)/y
    
    return sr

# %%
cagr = []
vol = []
sr = []
rf = 0.06
for i in range(len(name)):
    x = CAGR(df, name[i])
    y = volatility(df, name[i])
    z = sharpe(x,y,rf)
    cagr.append(x)
    vol.append(y)
    sr.append(z)

#PRINT CAGR, VOL, SR LIST
print(sr)
# Out:
# [1.9718855272895255, 0.43466895807663714, 0.7478670631843248, 0.9354528352659844, 0.07007871800410821, -0.05403963418946746, 0.9478653586218079, 1.1281658879181775, 0.3783039230739595, -0.20745335508296692, 0.5671637013297235, 0.1692217635071075, -0.6301791698269318, 1.0763576496092573, 0.12959370075400317, -0.09365076959712157, 0.3895806263601335, 0.7174438810664896, 0.3391500508681632, 0.5543671658821857, -0.33377894868595837, 0.45247643440135926, 0.7445717720080879, 0.5710403952338242, -0.20243631907595153, 0.8716534618481141, -0.29000948452198994, 0.6910971926412667, 0.48461683576025816, 1.5547266824755859, 0.011079305753349228, 0.010387329556847406, 0.8735965703107177, -0.2959392732171445, -0.32540109089302427, 0.08627930812001329, 0.9084105668611957, 0.2024178109108367, -0.0021370259141654606, 1.0928544139831908, -0.12788713222797335, 0.4556871960939803, 0.7786866127483469, 0.765183273578455, 1.2943582327462886, 0.40515368790811634, 0.1420993635072126, 0.9642285074077204]

# %% [markdown]
# # IDENTIFY THE TOP 10 STOCKS BY COMPARING THE SHARPE RATIO LIST AND MAKE A LIST OF THE STOCK NAMES

# %%
df_sr = pd.DataFrame(name)
df_sr["Sharpe Ratio"] = sr
df_sr.rename(columns = {'0':'Company'}, inplace = True)
df_sr
# Out:
#                 0  Sharpe Ratio
# 0     ADANIENT.NS      1.971886
# 1   ADANIPORTS.NS      0.434669
# 2   APOLLOHOSP.NS      0.747867
# 3   ASIANPAINT.NS      0.935453
# 4     AXISBANK.NS      0.070079
# 5   BAJAJ-AUTO.NS     -0.054040
# 6   BAJAJFINSV.NS      0.947865
# 7   BAJFINANCE.NS      1.128166
# 8   BHARTIARTL.NS      0.378304
# 9         BPCL.NS     -0.207453
# 10   BRITANNIA.NS      0.567164
# 11       CIPLA.NS      0.169222
# 12   COALINDIA.NS     -0.630179
# 13    DIVISLAB.NS      1.076358
# 14     DRREDDY.NS      0.129594
# 15   EICHERMOT.NS     -0.093651
# 16      GRASIM.NS      0.389581
# 17     HCLTECH.NS      0.717444
# 18        HDFC.NS      0.339150
# 19    HDFCBANK.NS      0.554367
# 20  HEROMOTOCO.NS     -0.333779
# 21    HINDALCO.NS      0.452476
# 22  HINDUNILVR.NS      0.744572
# 23   ICICIBANK.NS      0.571040
# 24  INDUSINDBK.NS     -0.202436
# 25        INFY.NS      0.871653
# 26         ITC.NS     -0.290009
# 27    JSWSTEEL.NS      0.691097
# 28   KOTAKBANK.NS      0.484617
# 29         LTI.NS      1.554727
# 30         M&M.NS      0.011079
# 31      MARUTI.NS      0.010387
# 32   NESTLEIND.NS      0.873597
# 33        NTPC.NS     -0.295939
# 34        ONGC.NS     -0.325401
# 35   POWERGRID.NS      0.086279
# 36    RELIANCE.NS      0.908411
# 37        SBIN.NS      0.202418
# 38   SUNPHARMA.NS     -0.002137
# 39  TATACONSUM.NS      1.092854
# 40  TATAMOTORS.NS     -0.127887
# 41   TATASTEEL.NS      0.455687
# 42         TCS.NS      0.778687
# 43       TECHM.NS      0.765183
# 44       TITAN.NS      1.294358
# 45  ULTRACEMCO.NS      0.405154
# 46         UPL.NS      0.142099
# 47       WIPRO.NS      0.964229

# %%
df_sr.sort_values(by = "Sharpe Ratio", ascending = False, inplace = True)
df_sr
# Out:
#                 0  Sharpe Ratio
# 0     ADANIENT.NS      1.971886
# 29         LTI.NS      1.554727
# 44       TITAN.NS      1.294358
# 7   BAJFINANCE.NS      1.128166
# 39  TATACONSUM.NS      1.092854
# 13    DIVISLAB.NS      1.076358
# 47       WIPRO.NS      0.964229
# 6   BAJAJFINSV.NS      0.947865
# 3   ASIANPAINT.NS      0.935453
# 36    RELIANCE.NS      0.908411
# 32   NESTLEIND.NS      0.873597
# 25        INFY.NS      0.871653
# 42         TCS.NS      0.778687
# 43       TECHM.NS      0.765183
# 2   APOLLOHOSP.NS      0.747867
# 22  HINDUNILVR.NS      0.744572
# 17     HCLTECH.NS      0.717444
# 27    JSWSTEEL.NS      0.691097
# 23   ICICIBANK.NS      0.571040
# 10   BRITANNIA.NS      0.567164
# 19    HDFCBANK.NS      0.554367
# 28   KOTAKBANK.NS      0.484617
# 41   TATASTEEL.NS      0.455687
# 21    HINDALCO.NS      0.452476
# 1   ADANIPORTS.NS      0.434669
# 45  ULTRACEMCO.NS      0.405154
# 16      GRASIM.NS      0.389581
# 8   BHARTIARTL.NS      0.378304
# 18        HDFC.NS      0.339150
# 37        SBIN.NS      0.202418
# 11       CIPLA.NS      0.169222
# 46         UPL.NS      0.142099
# 14     DRREDDY.NS      0.129594
# 35   POWERGRID.NS      0.086279
# 4     AXISBANK.NS      0.070079
# 30         M&M.NS      0.011079
# 31      MARUTI.NS      0.010387
# 38   SUNPHARMA.NS     -0.002137
# 5   BAJAJ-AUTO.NS     -0.054040
# 15   EICHERMOT.NS     -0.093651
# 40  TATAMOTORS.NS     -0.127887
# 24  INDUSINDBK.NS     -0.202436
# 9         BPCL.NS     -0.207453
# 26         ITC.NS     -0.290009
# 33        NTPC.NS     -0.295939
# 34        ONGC.NS     -0.325401
# 20  HEROMOTOCO.NS     -0.333779
# 12   COALINDIA.NS     -0.630179

# %%
top_10 = df_sr.head(10)
top_10.columns =['Company', 'Sharpe Ratio']
top_10
# Out:
#           Company  Sharpe Ratio
# 0     ADANIENT.NS      1.971886
# 29         LTI.NS      1.554727
# 44       TITAN.NS      1.294358
# 7   BAJFINANCE.NS      1.128166
# 39  TATACONSUM.NS      1.092854
# 13    DIVISLAB.NS      1.076358
# 47       WIPRO.NS      0.964229
# 6   BAJAJFINSV.NS      0.947865
# 3   ASIANPAINT.NS      0.935453
# 36    RELIANCE.NS      0.908411

# %%
newlist = top_10['Company'].tolist()
newlist
# Out:
# ['ADANIENT.NS',
#  'LTI.NS',
#  'TITAN.NS',
#  'BAJFINANCE.NS',
#  'TATACONSUM.NS',
#  'DIVISLAB.NS',
#  'WIPRO.NS',
#  'BAJAJFINSV.NS',
#  'ASIANPAINT.NS',
#  'RELIANCE.NS']

# %%
df2 = pd.DataFrame()
for i in range(len(newlist)):
    df2[newlist[i]] = df1[newlist[i]]
    
df2
# Out:
#             ADANIENT.NS       LTI.NS     TITAN.NS  BAJFINANCE.NS  \
# DATE
# 02-01-2017    41.930149   680.299988   333.950012     870.049988
# 03-01-2017    41.712189   680.099976   348.149994     884.000000
# 04-01-2017    42.393314   698.000000   359.649994     871.900024
# 05-01-2017    43.128933   691.599976   358.049988     899.750000
# 06-01-2017    42.856480   680.049988   355.200012     878.450012
# ...                 ...          ...          ...            ...
# 27-12-2021  1730.199951  7181.250000  2331.300049    6890.750000
# 28-12-2021  1751.000000  7271.950195  2379.850098    6906.649902
# 29-12-2021  1718.050049  7263.100098  2402.149902    6911.649902
# 30-12-2021  1696.400024  7292.500000  2437.300049    6871.100098
# 31-12-2021  1709.449951  7332.000000  2522.399902    6977.299805
#
#             TATACONSUM.NS  DIVISLAB.NS    WIPRO.NS  BAJAJFINSV.NS  \
# DATE
# 02-01-2017     123.550003   797.849976  176.831299     294.964996
# 03-01-2017     124.449997   777.849976  175.125046     301.665009
# 04-01-2017     124.449997   752.299988  178.350037     296.084991
# 05-01-2017     125.199997   764.000000  180.150040     301.845001
# 06-01-2017     124.650002   737.400024  176.231293     297.855011
# ...                   ...          ...         ...            ...
# 27-12-2021     718.500000  4473.200195  699.599976    1601.310059
# 28-12-2021     726.950012  4525.350098  705.450012    1610.084961
# 29-12-2021     726.650024  4621.600098  703.700012    1624.905029
# 30-12-2021     728.000000  4627.899902  714.099976    1616.755005
# 31-12-2021     743.450012  4678.200195  715.349976    1640.619995
#
#             ASIANPAINT.NS  RELIANCE.NS
# DATE
# 02-01-2017     904.650024   537.455444
# 03-01-2017     896.599976   539.585266
# 04-01-2017     906.599976   528.564758
# 05-01-2017     916.500000   533.641602
# 06-01-2017     929.500000   532.428101
# ...                   ...          ...
# 27-12-2021    3272.399902  2370.250000
# 28-12-2021    3368.199951  2398.399902
# 29-12-2021    3367.449951  2402.500000
# 30-12-2021    3365.699951  2359.100098
# 31-12-2021    3382.949951  2368.149902
#
# [1236 rows x 10 columns]

# %%
df3 = pd.DataFrame()
for i in range(len(newlist)):
    b = []
    b.append(np.nan)
    for j in range(df2.shape[0] - 1):
        b.append(np.log(df1[newlist[i]][j+1]/df1[newlist[i]][j]))
    df3[newlist[i]] = b
    
df3 = df3.iloc[1:]
df3
# Out:
#       ADANIENT.NS    LTI.NS  TITAN.NS  BAJFINANCE.NS  TATACONSUM.NS  \
# 1       -0.005212 -0.000294  0.041642       0.015906       0.007258
# 2        0.016197  0.025979  0.032498      -0.013782       0.000000
# 3        0.017203 -0.009211 -0.004459       0.031442       0.006008
# 4       -0.006337 -0.016841 -0.007992      -0.023958      -0.004403
# 5        0.001271  0.001029 -0.001691      -0.000228       0.000802
# ...           ...       ...       ...            ...            ...
# 1231     0.018668  0.002049  0.005096       0.005639      -0.000626
# 1232     0.011950  0.012551  0.020611       0.002305       0.011692
# 1233    -0.018997 -0.001218  0.009327       0.000724      -0.000413
# 1234    -0.012682  0.004040  0.014527      -0.005884       0.001856
# 1235     0.007663  0.005402  0.034320       0.015338       0.021000
#
#       DIVISLAB.NS  WIPRO.NS  BAJAJFINSV.NS  ASIANPAINT.NS  RELIANCE.NS
# 1       -0.025387 -0.009696       0.022460      -0.008938     0.003955
# 2       -0.033399  0.018248      -0.018671       0.011092    -0.020635
# 3        0.015433  0.010042       0.019267       0.010861     0.009559
# 4       -0.035437 -0.021993      -0.013307       0.014085    -0.002277
# 5       -0.004417  0.004353       0.004723      -0.021092     0.002555
# ...           ...       ...            ...            ...          ...
# 1231     0.005818  0.001645       0.005796      -0.003782    -0.001075
# 1232     0.011591  0.008327       0.005465       0.028855     0.011806
# 1233     0.021046 -0.002484       0.009162      -0.000223     0.001708
# 1234     0.001362  0.014671      -0.005028      -0.000520    -0.018230
# 1235     0.010810  0.001749       0.014653       0.005112     0.003829
#
# [1235 rows x 10 columns]

# %%
np.random.seed(42)
num_ports = 6000*4
all_weights = np.zeros((num_ports, df3.shape[1]))
ret_arr = np.zeros(num_ports)
vol_arr = np.zeros(num_ports)
sharpe_arr = np.zeros(num_ports)

for x in range(num_ports):
    if x%6000 == 0:
        print(x)
    # Weights
    weights = np.array(np.random.random(df3.shape[1]))
    weights = weights/np.sum(weights)
    # Save weights
    all_weights[x,:] = weights
    # Expected return
    ret_arr[x] = np.sum((df3.mean() * weights*252))
    # Expected volatility
    vol_arr[x] = np.sqrt(np.dot(weights.T, np.dot(df3.cov()*252, weights)))
    # Sharpe Ratio
    sharpe_arr[x] = ret_arr[x]/vol_arr[x]
# Out:
# 0
# 6000
# 12000
# 18000

# %%
sharpe_arr.max()
# Out:
# 2.0721560871240494

# %%
sharpe_arr.max()
p = sharpe_arr.argmax()
print(all_weights[p,:])
# Out:
# [0.16981134 0.18839697 0.14167278 0.05446895 0.00399083 0.15939441
#  0.18597863 0.00336957 0.07648323 0.0164333 ]

# %%
mr = ret_arr[p]
mv = vol_arr[p]

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(12,8))
plt.scatter(vol_arr, ret_arr, c=sharpe_arr, cmap='viridis')
plt.colorbar(label='Sharpe Ratio')
plt.xlabel('Volatility')
plt.ylabel('Return')
plt.scatter(mv, mr,c='red', s=50) # red dot
plt.show()

# %%
fy = np.linspace(0.27,0.55,50)

# %%
def get_ret_vol_sr(weights):
    weights = np.array(weights)
    ret = np.sum(df3.mean() * weights) * 252
    vol = np.sqrt(np.dot(weights.T, np.dot(df3.cov()*252, weights)))
    sr = ret/vol
    return np.array([ret, vol, sr])

def min_vol(weights):
    return get_ret_vol_sr(weights)[1]

def check_sum(weights):
    #return 0 if sum of the weights is 1
    return np.sum(weights)-1

# %%
a = 1/10
c = ((0,1),)
b = []
d = ()
for i in range(10):
    b.append(a)
    d = d+c

# %%
from scipy.optimize import minimize
fx = []

for i in fy:
    print(i)
    cons = ({'type':'eq', 'fun':check_sum},
            {'type':'eq', 'fun': lambda w: get_ret_vol_sr(w)[0] - i})
    
    result = minimize(min_vol, b, method='SLSQP', bounds=d, constraints=cons)
    fx.append(result['fun'])
# Out:
# 0.27
# 0.27571428571428575
# 0.2814285714285715
# 0.28714285714285714
# 0.29285714285714287
# 0.2985714285714286
# 0.3042857142857143
# 0.31000000000000005
# 0.3157142857142857
# 0.32142857142857145
# 0.3271428571428572
# 0.33285714285714285
# 0.33857142857142863
# 0.3442857142857143
# 0.35000000000000003
# 0.35571428571428576
# 0.36142857142857143
# 0.36714285714285716
# 0.3728571428571429
# 0.3785714285714286
# 0.38428571428571434
# 0.39
# 0.39571428571428574
# 0.40142857142857147
# 0.4071428571428572
# 0.4128571428571429
# 0.4185714285714286
# 0.4242857142857143
# 0.43000000000000005
# 0.4357142857142857
# 0.4414285714285715
# 0.4471428571428572
# 0.4528571428571429
# 0.45857142857142863
# 0.4642857142857143
# 0.4700000000000001
# 0.47571428571428576
# 0.4814285714285715
# 0.4871428571428572
# 0.4928571428571429
# 0.4985714285714286
# 0.5042857142857143
# 0.51
# 0.5157142857142858
# 0.5214285714285715
# 0.5271428571428571
# 0.5328571428571429
# 0.5385714285714287
# 0.5442857142857144
# 0.55

# %%
plt.figure(figsize=(15,8))
plt.scatter(vol_arr, ret_arr, c=sharpe_arr, cmap='viridis')
plt.colorbar(label='Sharpe Ratio')
plt.xlabel('Volatility')
plt.ylabel('Return')
plt.plot(fx,fy, 'r--', linewidth=3)
plt.savefig('cover.png')
plt.show()

# %%
mon = all_weights[p,:]*1e7
mon
# Out:
# array([1698113.43304914, 1883969.70575444, 1416727.81801344,
#         544689.52291032,   39908.28179233, 1593944.05004851,
#        1859786.27401697,   33695.65587912,  764832.27904879,
#         164332.97948694])

# %%
num_sto = []
for i in range(len(mon)):
    num_sto.append(mon[i]/df2[newlist[i]][-1])

# %%
num_sto
# Out:
# [993.3683241534914,
#  256.9516783625809,
#  561.6586873834425,
#  78.06594787857547,
#  53.67984551505629,
#  340.7173664248275,
#  2599.8271285563987,
#  20.53836719155587,
#  226.0844204398298,
#  69.3929802957783]

# %%
newlist
# Out:
# ['ADANIENT.NS',
#  'LTI.NS',
#  'TITAN.NS',
#  'BAJFINANCE.NS',
#  'TATACONSUM.NS',
#  'DIVISLAB.NS',
#  'WIPRO.NS',
#  'BAJAJFINSV.NS',
#  'ASIANPAINT.NS',
#  'RELIANCE.NS']

# %%
DF = pd.DataFrame()
DF["Name"] = newlist
DF["No. of shares"] = num_sto
DF
# Out:
#             Name  No. of shares
# 0    ADANIENT.NS     993.368324
# 1         LTI.NS     256.951678
# 2       TITAN.NS     561.658687
# 3  BAJFINANCE.NS      78.065948
# 4  TATACONSUM.NS      53.679846
# 5    DIVISLAB.NS     340.717366
# 6       WIPRO.NS    2599.827129
# 7  BAJAJFINSV.NS      20.538367
# 8  ASIANPAINT.NS     226.084420
# 9    RELIANCE.NS      69.392980

# %%
import pandas_datareader.data as pdr
import datetime as dt
from statistics import stdev

# %%
fin = dt.datetime(2022, 10, 30)
ini = dt.datetime(2022, 5, 1)

# %%
newdf = pd.DataFrame()
import yfinance as yf 

yf.pdr_override()

newdf = pd.DataFrame()
for i in range(len(newlist)):
    try:
        o = pdr.get_data_yahoo(newlist[i],ini,fin)
        newdf[str(newlist[i])] = o["Close"]
    except:
        print('error')
        print(i)
o = pdr.get_data_yahoo('^NSEI',ini,fin)
newdf['Nifty50'] = o["Close"]
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
newdf
# Out:
#             ADANIENT.NS       LTI.NS     TITAN.NS  BAJFINANCE.NS  \
# Date
# 2022-05-02  2339.500000  4716.649902  2386.550049    6626.149902
# 2022-05-04  2253.800049  4738.149902  2289.949951    6339.750000
# 2022-05-05  2255.399902  4765.200195  2262.000000    6309.450195
# 2022-05-06  2247.699951  4593.000000  2208.750000    6000.299805
# 2022-05-09  2197.649902  4448.899902  2183.199951    6036.950195
# ...                 ...          ...          ...            ...
# 2022-10-21  3311.899902  4765.250000  2665.649902    7192.750000
# 2022-10-24  3309.800049  4738.299805  2683.899902    7206.500000
# 2022-10-25  3300.500000  4809.700195  2670.300049    7102.899902
# 2022-10-27  3325.000000  4676.250000  2703.800049    6971.100098
# 2022-10-28  3323.300049  4584.149902  2736.399902    7006.850098
#
#             TATACONSUM.NS  DIVISLAB.NS    WIPRO.NS  BAJAJFINSV.NS  \
# Date
# 2022-05-02     824.400024  4509.649902  495.000000    1495.744995
# 2022-05-04     803.299988  4344.149902  491.750000    1432.244995
# 2022-05-05     776.349976  4365.799805  501.149994    1413.925049
# 2022-05-06     764.950012  4165.850098  485.100006    1364.050049
# 2022-05-09     758.250000  4231.100098  483.149994    1378.385010
# ...                   ...          ...         ...            ...
# 2022-10-21     761.650024  3571.399902  382.549988    1684.449951
# 2022-10-24     770.950012  3612.449951  384.700012    1701.800049
# 2022-10-25     766.950012  3597.149902  384.649994    1658.550049
# 2022-10-27     770.049988  3621.050049  382.649994    1630.949951
# 2022-10-28     761.349976  3547.500000  383.250000    1653.400024
#
#             ASIANPAINT.NS  RELIANCE.NS       Nifty50
# Date
# 2022-05-02    3200.000000  2780.449951  17069.099609
# 2022-05-04    3100.850098  2693.649902  16677.599609
#
# [124 rows x 12 columns]

# %%
Return_P = ((newdf['Portfolio'][-1] - newdf['Portfolio'][0]) / newdf['Portfolio'][0])*100
Return_B = ((newdf['Nifty50'][-1] - newdf['Nifty50'][0]) / newdf['Nifty50'][0])*100

print('Total Return on Portfolio in %: ', Return_P, '%')
print('Total Return on Benchmark in %: ', Return_B, '%')
# Out:
# Total Return on Portfolio in %:  5.431491542902385 %
# Total Return on Benchmark in %:  4.2046809046729745 %

# %%
x = newdf["Portfolio"].pct_change()
vol_P = x.std()*np.sqrt(120)*100
x1 = newdf["Nifty50"].pct_change()
vol_B = x1.std()*np.sqrt(120)*100

print('Volatility of Portfolio in %: ', vol_P, '%')
print('Volatility of Benchmark in %: ', vol_B, '%')
# Out:
# Volatility of Portfolio in %:  15.554003129514848 %
# Volatility of Benchmark in %:  11.448813910606127 %

# %%
newdf['daily_ret_B'] = newdf["Nifty50"].pct_change()
newdf['daily_ret_P'] = newdf["Portfolio"].pct_change()

p = newdf['daily_ret_P'].dropna()
q = newdf['daily_ret_B'].dropna()
beta = np.cov(p,q)[0][1]/np.var(q)
print('Beta of Portfolio: ', beta)
# Out:
# Beta of Portfolio:  1.121718919168848

# %%
rf = 0.06
rfp = ((1+rf)**(180/365) -1)*100
alpha = Return_P - rfp - beta*(Return_B - rfp)
print('Alpha of Portfolio in %: ', alpha, '%')
# Out:
# Alpha of Portfolio in %:  1.0698587935368877 %

# %%
sr = (Return_P - rfp)/vol_P
print('Sharpe Ratio of Portfolio: ', sr)
sb = (Return_B - rfp)/vol_B
print('Sharpe Ratio of Benchmark: ', sb)
# Out:
# Sharpe Ratio of Portfolio:  0.1617764887134183
# Sharpe Ratio of Benchmark:  0.11262838085842854

# %%
tr = (Return_P - rfp)/beta
print("Treynor for portfolio", tr)
rfp
# Out:
# Treynor for portfolio 2.2432286455459765
# 2.915219531171953

# %%
tr = (Return_B - rfp)/beta
print("Treynor for benchmark", tr)
rfp
# Out:
# Treynor for benchmark 1.1495405412761197
# 2.915219531171953

# %%
newdf["daily_ret_P"] = newdf["Portfolio"].pct_change()
newdf["cum_return"] = (1 + newdf["daily_ret_P"]).cumprod()
newdf["cum_roll_max"] = newdf["cum_return"].cummax()
newdf["drawdown"] = newdf["cum_roll_max"] - newdf["cum_return"]
newdf["drawdown_pct"] = newdf["drawdown"]/newdf["cum_roll_max"]
max_dd = newdf["drawdown_pct"].max()
print('Maximum Draw-down of Portfolio in %: ', max_dd*100, '%')
# Out:
# Maximum Draw-down of Portfolio in %:  14.288259934557907 %

# %%
newdf["daily_ret_B"] = newdf["Nifty50"].pct_change()
newdf["cum_return_B"] = (1 + newdf["daily_ret_B"]).cumprod()
newdf["cum_roll_max_B"] = newdf["cum_return_B"].cummax()
newdf["drawdown_B"] = newdf["cum_roll_max_B"] - newdf["cum_return_B"]
newdf["drawdown_pct_B"] = newdf["drawdown_B"]/newdf["cum_roll_max_B"]
max_dd_B = newdf["drawdown_pct_B"].max()
print('Maximum Draw-down of Benchmark in %: ', max_dd_B*100, '%')
# Out:
# Maximum Draw-down of Benchmark in %:  8.326916635534424 %

# %%
x = newdf["Portfolio"].pct_change()
y = []
count=0
for i in range(len(x)):
    if x[i] < 0:
        y.append(x[i])
        count=count+1
print(y)
neg_vol = stdev(y)*np.sqrt(count)*100

sor = (Return_P - rfp)/neg_vol
print('Sortino Ratio of Portfolio: ', sor)
# Out:
# [-0.02735920452442231, -0.02592224226047446, -0.010386117690478702, -0.01498401274643224, -0.006936095827655642, -0.02057934113246851, -0.0009430446260886294, -0.03674457357583072, -0.014251310700511, -0.020030999442997466, -0.03533311289312979, -0.0002580075127418535, -0.009475628631619326, -0.005311461849643151, -0.013396318606727742, -0.002770190028739239, -0.00886466475216019, -0.037273832082000635, -0.028999998078886646, -0.019111239068036356, -0.02225192524980224, -0.005077994254810703, -0.009207357083956702, -0.007601535965448325, -0.006641505118119895, -0.005916634747395455, -0.003607657177817525, -0.012449144423277936, -0.001989082802926312, -0.0071033503811863685, -0.010937904897488027, -0.02601332320287386, -0.0011776355295385343, -0.007888479804211701, -0.008926486877615991, -0.001315581616576189, -0.003510811526406532, -0.01990446582304306, -0.022754565586254993, -0.009867063641867735, -0.010170889797092575, -0.001041068625037389, -0.019185135224770056, -0.03363129215300187, -0.00776121789921147, -0.011721949221038308, -0.0032232251881344487, -0.010888542910396093, -0.0005283589381653853, -0.008329118459279972, -0.002461998709797797, -0.0007793531966358014, -0.002087065905787888]
# Sortino Ratio of Portfolio:  0.33601826933676493

# %%
x = newdf["Nifty50"].pct_change()
y = []
for i in range(len(x)):
    if x[i] < 0:
        y.append(x[i])
print(y)
neg_vol = stdev(y)*np.sqrt(115)*100

sor = (Return_B - rfp)/neg_vol
print('Sortino Ratio of Benchmark: ', sor)
# Out:
# [-0.022936183451936376, -0.0162684216398562, -0.006666182687180999, -0.003790968888092272, -0.0044919933245182175, -0.022211752141785834, -0.0016352232651188903, -0.0011685620062508173, -0.026532725334179386, -0.0031630222318707046, -0.005522754266735541, -0.006161219184365629, -0.004612433983534836, -0.0037264067061659745, -0.002628050201467391, -0.0008893953501298846, -0.009245946006475991, -0.0036609606157923524, -0.016767698414100085, -0.026379749115209128, -0.00268160945598539, -0.0025393443813560568, -0.021128447854290244, -0.00436829362663993, -0.014419265085317434, -0.0032239710103227903, -0.001193081241402827, -0.0017870563085186086, -0.0015471713984448465, -0.00028356592763323363, -0.0097249750439381, -0.005707292501522909, -0.0017536552323109689, -0.005290199311757782, -0.00884795806776506, -0.0003537116074355806, -0.011029475746944017, -0.0150773300473388, -0.004686182219266755, -0.014009988924553851, -0.012190795272107646, -0.0001910505934481499, -0.0005774531254664206, -0.0017671004916441913, -0.0036690976717561608, -0.007017960667916379, -0.019384853148544656, -0.005495005437451739, -0.004997577656902563, -0.017155677232420508, -0.017951321762256445, -0.0005230508522044985, -0.00874917846539458, -0.0024023347691036756, -0.012109264448790458, -0.0009895331040011834, -0.00425364584114718, -0.014932383199930399, -0.006380083772817624, -0.004196122026705051]
# Sortino Ratio of Benchmark:  0.1687629966634262
